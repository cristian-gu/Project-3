# %%
import pandas as pd
import numpy as np
import re
import os

# %%
path = 'Resources\CountyMortgagesPercent-30-89DaysLate-thru-2022-12.csv'
df = pd.read_csv(path)
df.head()
# Out:
#   RegionType State              Name FIPSCode  2008-01  2008-02  2008-03  \
# 0   National   NaN     United States    -----      3.5      3.2      3.1
# 1     County    AL    Baldwin County  '01003'      2.8      3.1      3.2
# 2     County    AL  Jefferson County  '01073'      5.1      4.6      4.5
# 3     County    AL        Lee County  '01081'      3.8      4.5      4.2
# 4     County    AL    Madison County  '01089'      3.5      3.3      3.3
#
#    2008-04  2008-05  2008-06  ...  2022-03  2022-04  2022-05  2022-06  \
# 0      3.1      3.2      3.2  ...      1.0      0.9      1.1      1.0
# 1      2.5      2.7      2.7  ...      0.9      0.7      0.9      0.8
# 2      4.9      4.9      5.0  ...      1.4      1.5      1.7      1.7
# 3      3.6      3.8      4.4  ...      0.9      0.6      1.2      1.0
# 4      3.0      3.3      3.2  ...      1.0      1.0      1.1      0.8
#
#    2022-07  2022-08  2022-09  2022-10  2022-11  2022-12
# ...

# %%
## find total number of null values
pd.isnull(df).sum()
# Out:
# RegionType    0
# State         1
# Name          0
# FIPSCode      0
# 2008-01       0
#              ..
# 2022-08       0
# 2022-09       0
# 2022-10       0
# 2022-11       0
# 2022-12       0
# Length: 184, dtype: int64

# %%
df[df["State"].isnull() == True]
# Out:
#   RegionType State           Name FIPSCode  2008-01  2008-02  2008-03  \
# 0   National   NaN  United States    -----      3.5      3.2      3.1
#
#    2008-04  2008-05  2008-06  ...  2022-03  2022-04  2022-05  2022-06  \
# 0      3.1      3.2      3.2  ...      1.0      0.9      1.1      1.0
#
#    2022-07  2022-08  2022-09  2022-10  2022-11  2022-12
# 0      1.2      1.2      1.1      1.3      1.2      1.4
#
# [1 rows x 184 columns]

# %%
anomoly = df["FIPSCode"].unique().tolist()
anomoly[0]
# Out:
# '-----'

# %%
df["FIPSCode"] = df["FIPSCode"].replace({anomoly[0]: np.NaN})
df.head()
# Out:
#   RegionType State              Name FIPSCode  2008-01  2008-02  2008-03  \
# 0   National   NaN     United States      NaN      3.5      3.2      3.1
# 1     County    AL    Baldwin County  '01003'      2.8      3.1      3.2
# 2     County    AL  Jefferson County  '01073'      5.1      4.6      4.5
# 3     County    AL        Lee County  '01081'      3.8      4.5      4.2
# 4     County    AL    Madison County  '01089'      3.5      3.3      3.3
#
#    2008-04  2008-05  2008-06  ...  2022-03  2022-04  2022-05  2022-06  \
# 0      3.1      3.2      3.2  ...      1.0      0.9      1.1      1.0
# 1      2.5      2.7      2.7  ...      0.9      0.7      0.9      0.8
# 2      4.9      4.9      5.0  ...      1.4      1.5      1.7      1.7
# 3      3.6      3.8      4.4  ...      0.9      0.6      1.2      1.0
# 4      3.0      3.3      3.2  ...      1.0      1.0      1.1      0.8
#
#    2022-07  2022-08  2022-09  2022-10  2022-11  2022-12
# ...

# %%
df.dtypes
# Out:
# RegionType     object
# State          object
# Name           object
# FIPSCode       object
# 2008-01       float64
#                ...
# 2022-08       float64
# 2022-09       float64
# 2022-10       float64
# 2022-11       float64
# 2022-12       float64
# Length: 184, dtype: object

# %%
col_list = df.columns.tolist()
dates = col_list[28:]
print(dates)
df_time_col = df[dates]
df_time_col.head()
# Out:
# ['2010-01', '2010-02', '2010-03', '2010-04', '2010-05', '2010-06', '2010-07', '2010-08', '2010-09', '2010-10', '2010-11', '2010-12', '2011-01', '2011-02', '2011-03', '2011-04', '2011-05', '2011-06', '2011-07', '2011-08', '2011-09', '2011-10', '2011-11', '2011-12', '2012-01', '2012-02', '2012-03', '2012-04', '2012-05', '2012-06', '2012-07', '2012-08', '2012-09', '2012-10', '2012-11', '2012-12', '2013-01', '2013-02', '2013-03', '2013-04', '2013-05', '2013-06', '2013-07', '2013-08', '2013-09', '2013-10', '2013-11', '2013-12', '2014-01', '2014-02', '2014-03', '2014-04', '2014-05', '2014-06', '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12', '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06', '2017-0
# ...

# %%
list10 = []
list11 = []
list12 = []
list13 = []
list14 = []
list15 = []
list16 = []
list17 = []
list18 = []
list19 = []
list20 = []
list21 = []
list22 = []



# def ave_action(counter, temp_list)

for i in range(len(df_time_col)):
    for j, value in enumerate(df_time_col.iloc[i]):
        if re.findall('^[0-9]+', dates[j]) == ['2010']:
            list10.append((value, i))
            
        elif re.findall('^[0-9]+', dates[j]) == ['2011']:
            list11.append((value, i))
            
        elif re.findall('^[0-9]+', dates[j]) == ['2012']:
            list12.append((value, i))
            
        elif re.findall('^[0-9]+', dates[j]) == ['2013']:
            list13.append((value, i))
            
        elif re.findall('^[0-9]+', dates[j]) == ['2014']:
            list14.append((value, i))
            
        elif re.findall('^[0-9]+', dates[j]) == ['2015']:
            list15.append((value, i))
            
        elif re.findall('^[0-9]+', dates[j]) == ['2016']:
            list16.append((value, i))
            
        elif re.findall('^[0-9]+', dates[j]) == ['2017']:
            list17.append((value, i))
            
        elif re.findall('^[0-9]+', dates[j]) == ['2018']:
            list18.append((value, i))
            
        elif re.findall('^[0-9]+', dates[j]) == ['2019']:
            list19.append((value, i))
            
        elif re.findall('^[0-9]+', dates[j]) == ['2020']:
            list20.append((value, i))
            
        elif re.findall('^[0-9]+', dates[j]) == ['2021']:
            list21.append((value, i))
            
        elif re.findall('^[0-9]+', dates[j]) == ['2022']:
            list22.append((value, i))
            
print(list10)
years_list = [list10, list11, list12, list13, list14, list15, list16, list17, list18, list19, list20, list21, list22]
# Out:
# [(4.0, 0), (3.8, 0), (3.4, 0), (3.3, 0), (3.5, 0), (3.5, 0), (3.7, 0), (3.7, 0), (3.7, 0), (3.7, 0), (3.6, 0), (3.7, 0), (4.7, 1), (4.2, 1), (3.5, 1), (3.8, 1), (3.0, 1), (3.5, 1), (3.3, 1), (3.1, 1), (3.6, 1), (3.2, 1), (3.2, 1), (3.3, 1), (6.2, 2), (5.4, 2), (5.5, 2), (5.2, 2), (5.4, 2), (5.3, 2), (5.7, 2), (5.7, 2), (5.5, 2), (5.7, 2), (5.8, 2), (6.0, 2), (4.3, 3), (3.5, 3), (3.1, 3), (3.4, 3), (2.8, 3), (3.4, 3), (4.0, 3), (4.2, 3), (4.6, 3), (3.9, 3), (3.9, 3), (3.6, 3), (3.7, 4), (3.3, 4), (3.1, 4), (2.9, 4), (3.2, 4), (3.2, 4), (3.5, 4), (3.2, 4), (3.5, 4), (3.5, 4), (3.7, 4), (4.0, 4), (7.0, 5), (6.4, 5), (5.0, 5), (5.3, 5), (5.7, 5), (5.9, 5), (5.6, 5), (5.7, 5), (6.1, 5), (5.9, 5), (6.3, 5), (6.6, 5), (6.7, 6), (6.0, 6), (5.3, 6), (5.9, 6), (5.9, 6), (6.9, 6), (7.0, 6), (6.2, 6), (6.4, 6), (5.8, 6), (5.9, 6), (5.4, 6), (4.2, 7), (3.7, 7), (3.1, 7), (3.7, 7), (3.5, 7), (4.0, 7), (3.5, 7), (3.8, 7), (3.6, 7), (3.9, 7), (3.9, 7), (3.7, 7), (5.4, 8), (6.0, 8), (5.0, 8), (5.1, 8
# ...

# %%
# def average(val):
#     temp_list = []
#     temp_list.append(val)
#     counter = len(temp_list)
#     average_val = average_action(counter_temp)
#     return (counter, temp_list)

def average(temp_list):
    average_val = round(np.average(temp_list), 2)
    return (average_val)

# %%
def ave_op(list_num):
    temp_list = []
    avg_list = []

    for i in range(1, len(list_num)):
        if list_num[i][1] == list_num[i-1][1]:
            temp_list.append(list_num[i-1][0])
        else:
            temp_list.append(list10[i-1][0])
            holder = average(temp_list)
            avg_list.append(holder)
            temp_list = []
    holder=average(temp_list)
    avg_list.append(holder)
    return (avg_list)

#         print(temp_list)

# %%
date_column = []
date_int = 2010
while date_int <= 2022:
    date_column.append(date_int)
    date_int +=1
    
# print(date_column)

avg_years_list = {}

for i in range(len(years_list)):
    avg_years_list[date_column[i]] = ave_op(years_list[i])
    
print(avg_years_list)
# Out:
# {2010: [3.63, 3.53, 5.62, 3.72, 3.4, 5.96, 6.12, 3.72, 5.45, 2.43, 4.0, 3.39, 3.62, 4.84, 3.14, 5.28, 3.03, 4.47, 3.81, 3.56, 2.44, 3.44, 2.82, 2.66, 4.05, 4.39, 3.32, 1.27, 3.68, 3.01, 2.43, 2.54, 2.45, 4.47, 3.29, 4.63, 2.74, 1.52, 3.94, 2.4, 1.9, 2.57, 2.02, 1.99, 3.14, 3.66, 2.23, 4.01, 4.31, 2.78, 2.39, 3.97, 2.91, 1.24, 2.72, 1.97, 2.46, 2.41, 1.76, 3.21, 3.85, 3.1, 2.61, 3.48, 3.46, 2.85, 3.96, 3.4, 2.38, 5.0, 4.16, 2.78, 3.07, 3.03, 3.05, 3.48, 4.18, 2.99, 4.07, 2.58, 5.05, 4.36, 4.11, 4.18, 3.21, 4.17, 2.84, 3.14, 3.57, 4.95, 2.58, 4.4, 2.77, 4.18, 4.83, 3.41, 4.04, 3.64, 4.89, 2.81, 4.37, 3.43, 2.97, 3.5, 4.38, 4.9, 3.97, 9.22, 3.98, 2.96, 4.48, 5.71, 6.67, 2.75, 2.99, 4.08, 4.88, 4.96, 6.78, 3.68, 4.17, 6.15, 5.53, 3.43, 1.98, 3.12, 2.66, 4.75, 2.77, 2.18, 3.65, 2.42, 3.03, 3.99, 2.72, 3.06, 2.92, 3.44, 3.19, 2.98, 3.75, 2.37, 3.08, 3.78, 4.23, 3.58, 4.41, 2.64, 3.42, 3.31, 4.47, 4.66, 3.96, 4.48, 3.07, 3.95, 1.46, 1.77, 3.0, 2.56, 2.13, 3.78, 3.2, 5.75, 3.22, 3.53, 3.52, 
# ...

# %%
## Combine the new dataset
avg_years_df = pd.DataFrame(avg_years_list)
avg_years_df = avg_years_df.reset_index(level=0)

# %%
location_df = df.copy()
location_df = location_df.reset_index(level=0)
location_df = location_df[["index", "RegionType", "State", "Name", "FIPSCode"]]

# %%
new_df = pd.merge(location_df, avg_years_df, how = 'inner', on= 'index')
new_df.head()
# Out:
#    index RegionType State              Name FIPSCode  2010  2011  2012  2013  \
# 0      0   National   NaN     United States      NaN  3.63  3.33  3.29  2.90
# 1      1     County    AL    Baldwin County  '01003'  3.53  2.97  3.04  3.03
# 2      2     County    AL  Jefferson County  '01073'  5.62  4.94  4.93  4.52
# 3      3     County    AL        Lee County  '01081'  3.72  3.41  3.90  3.59
# 4      4     County    AL    Madison County  '01089'  3.40  3.50  3.79  3.37
#
#    2014  2015  2016  2017  2018  2019  2020  2021  2022
# 0  2.52  2.36  2.27  2.19  2.10  2.05  1.42  1.03  1.29
# 1  2.30  2.17  1.97  2.14  2.11  2.27  1.42  1.07  1.08
# 2  3.89  3.78  3.66  3.52  3.53  3.34  2.27  1.68  1.97
# 3  2.82  3.22  2.58  2.40  2.41  2.14  1.40  1.08  1.32
# 4  2.99  2.63  2.51  2.33  2.24  2.15  1.41  0.94  1.22

# %%
## Create the modified dataset
df_10 = new_df[["RegionType", "State", "Name", 2010]]
df_11 = new_df[["RegionType", "State", "Name", 2011]]
df_12 = new_df[["RegionType", "State", "Name", 2012]]
df_13 = new_df[["RegionType", "State", "Name", 2013]]
df_14 = new_df[["RegionType", "State", "Name", 2014]]
df_15 = new_df[["RegionType", "State", "Name", 2015]]
df_16 = new_df[["RegionType", "State", "Name", 2016]]
df_17 = new_df[["RegionType", "State", "Name", 2017]]
df_18 = new_df[["RegionType", "State", "Name", 2018]]
df_19 = new_df[["RegionType", "State", "Name", 2019]]
df_20 = new_df[["RegionType", "State", "Name", 2020]]
df_21 = new_df[["RegionType", "State", "Name", 2021]]
df_22 = new_df[["RegionType", "State", "Name", 2022]]

year10 = []
year11 = []
year12 = []
year13 = []
year14 = []
year15 = []
year16 = []
year17 = []
year18 = []
year19 = []
year20 = []
year21 = []
year22 = []

year_list = [year10, year11, year12, year13, year14, year15, year16, year17, year18, year19, year20, year21, year22]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

def add_year(year_list, year):
    for i in range(len(new_df)):
        year_list.append(year)
    return(year_list)

for i, val in enumerate(year_list):
    add_year(val, years[i])
    
print(year_list[0])
# Out:
# [2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2
# ...

# %%
df_10["Year"] = year_list[0]
df_11["Year"] = year_list[1]
df_12["Year"] = year_list[2]
df_13["Year"] = year_list[3]
df_14["Year"] = year_list[4]
df_15["Year"] = year_list[5]
df_16["Year"] = year_list[6]
df_17["Year"] = year_list[7]
df_18["Year"] = year_list[8]
df_19["Year"] = year_list[9]
df_20["Year"] = year_list[10]
df_21["Year"] = year_list[11]
df_22["Year"] = year_list[12]

df_10 = df_10.rename(columns = {2010: "Percentage_late"})
df_11 = df_11.rename(columns = {2011: "Percentage_late"})
df_12 = df_12.rename(columns = {2012: "Percentage_late"})
df_13 = df_13.rename(columns = {2013: "Percentage_late"})
df_14 = df_14.rename(columns = {2014: "Percentage_late"})
df_15 = df_15.rename(columns = {2015: "Percentage_late"})
df_16 = df_16.rename(columns = {2016: "Percentage_late"})
df_17 = df_17.rename(columns = {2017: "Percentage_late"})
df_18 = df_18.rename(columns = {2018: "Percentage_late"})
df_19 = df_19.rename(columns = {2019: "Percentage_late"})
df_20 = df_20.rename(columns = {2020: "Percentage_late"})
df_21 = df_21.rename(columns = {2021: "Percentage_late"})
df_22 = df_22.rename(columns = {2022: "Percentage_late"})
# Out:
# C:\Users\guerr\AppData\Local\Temp\ipykernel_27852\3441696959.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_11["Year"] = year_list[1]
# C:\Users\guerr\AppData\Local\Temp\ipykernel_27852\3441696959.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12["Year"] = year_list[2]
# C:\Users\guerr\AppData\Local\Temp\ipykernel_27852\3441696959.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_22.head()
# Out:
#   RegionType State              Name  Percentage_late  Year
# 0   National   NaN     United States             1.29  2022
# 1     County    AL    Baldwin County             1.08  2022
# 2     County    AL  Jefferson County             1.97  2022
# 3     County    AL        Lee County             1.32  2022
# 4     County    AL    Madison County             1.22  2022

# %%
## Link to how to Concatenate
mortgage_avg_dayslate_df = pd.concat([df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17, df_18, df_19, df_20, df_21, df_22])
mortgage_avg_dayslate_df
# Out:
#     RegionType State               Name  Percentage_late  Year
# 0     National   NaN      United States             3.63  2010
# 1       County    AL     Baldwin County             3.53  2010
# 2       County    AL   Jefferson County             5.62  2010
# 3       County    AL         Lee County             3.72  2010
# 4       County    AL     Madison County             3.40  2010
# ..         ...   ...                ...              ...   ...
# 467     County    WI      Racine County             1.10  2022
# 468     County    WI        Rock County             1.52  2022
# 469     County    WI  Washington County             0.53  2022
# 470     County    WI    Waukesha County             0.63  2022
# 471     County    WI   Winnebago County             0.45  2022
#
# [6136 rows x 5 columns]

# %%
mortgage_avg_dayslate_df.to_csv("Resources\mortgage_avg_dayslate.csv", encoding='utf8', index=False)
